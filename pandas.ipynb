# %% [markdown]
# <a href="https://colab.research.google.com/github/GopuJayaAkash/week1-ai-foundations/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Score_Prediction..csv')
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6

# %%
print(df.tail())
# Out:
#     student_id  age  gender  course  study_hours  class_attendance
# 15          16   23   other     bba         4.84              99.4
# 16          17   21    male    b.sc         1.97              91.9
# 17          18   18    male     bca         0.40              64.9
# 18          19   23  female    b.sc         4.28              98.1
# 19          20   20    male  b.tech         4.11              59.9

# %%
print(df.shape)
# Out:
# (20, 6)

# %%
print(df.columns)
# Out:
# Index(['student_id', 'age', 'gender', 'course', 'study_hours',
#        'class_attendance'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# student_id            int64
# age                   int64
# gender               object
# course               object
# study_hours         float64
# class_attendance    float64
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        20 non-null     int64
#  1   age               20 non-null     int64
#  2   gender            20 non-null     object
#  3   course            20 non-null     object
#  4   study_hours       20 non-null     float64
#  5   class_attendance  20 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.1+ KB
# None

# %%
print(df.describe())
# Out:
#        student_id        age  study_hours  class_attendance
# count    20.00000  20.000000    20.000000         20.000000
# mean     10.50000  20.800000     3.657000         73.100000
# std       5.91608   2.307881     2.222401         18.103155
# min       1.00000  17.000000     0.400000         44.800000
# 25%       5.75000  19.500000     1.815000         63.575000
# 50%      10.50000  21.500000     3.625000         70.300000
# 75%      15.25000  23.000000     5.000000         91.925000
# max      20.00000  24.000000     7.880000         99.400000

# %%
print(df.isnull().sum())
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# dtype: int64

# %%
print(df["age"])
# Out:
# 0     17
# 1     23
# 2     22
# 3     20
# 4     20
# 5     23
# 6     17
# 7     22
# 8     18
# 9     17
# 10    21
# 11    24
# 12    22
# 13    23
# 14    22
# 15    23
# 16    21
# 17    18
# 18    23
# 19    20
# Name: age, dtype: int64

# %%
print(df[["student_id", "study_hours"]])
# Out:
#     student_id  study_hours
# 0            1         2.78
# 1            2         3.37
# 2            3         7.88
# 3            4         0.67
# 4            5         0.89
# 5            6         3.48
# 6            7         1.35
# 7            8         5.48
# 8            9         2.89
# 9           10         6.77
# 10          11         5.99
# 11          12         3.77
# 12          13         6.76
# 13          14         0.81
# 14          15         4.65
# 15          16         4.84
# 16          17         1.97
# 17          18         0.40
# 18          19         4.28
# 19          20         4.11

# %%
print(df[df["study_hours"] > 5])
# Out:
#     student_id  age  gender course  study_hours  class_attendance
# 2            3   22    male   b.sc         7.88              76.8
# 7            8   22    male   b.sc         5.48              51.1
# 9           10   17    male    bba         6.77              44.8
# 10          11   21  female     ba         5.99              86.9
# 12          13   22  female     ba         6.76              46.4

# %%
print(df["study_hours"].mean())
# Out:
# 3.657000000000001

# %%
print(df["class_attendance"].max())
print(df["class_attendance"].min())
# Out:
# 99.4
# 44.8

# %%
print(df["gender"].value_counts())
# Out:
# gender
# male      10
# female     6
# other      4
# Name: count, dtype: int64

# %%
print(df.sort_values(by="study_hours", ascending=False))
# Out:
#     student_id  age  gender   course  study_hours  class_attendance
# 2            3   22    male     b.sc         7.88              76.8
# 9           10   17    male      bba         6.77              44.8
# 12          13   22  female       ba         6.76              46.4
# 10          11   21  female       ba         5.99              86.9
# 7            8   22    male     b.sc         5.48              51.1
# 15          16   23   other      bba         4.84              99.4
# 14          15   22    male   b.tech         4.65              75.1
# 18          19   23  female     b.sc         4.28              98.1
# 19          20   20    male   b.tech         4.11              59.9
# 11          12   24    male    b.com         3.77              96.6
# 5            6   23    male   b.tech         3.48              65.4
# 1            2   23   other      bca         3.37              64.8
# 8            9   18   other      bca         2.89              92.0
# ...

# %%
df["total_effort"] = df["study_hours"] * df["class_attendance"]
print(df.head())
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#    total_effort
# 0       258.262
# 1       218.376
# 2       605.184
# 3        32.428
# 4        63.724

# %%
df.to_csv("Updated_Score_Prediction.csv", index=False)
