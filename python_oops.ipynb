# %% [markdown]
# <a href="https://colab.research.google.com/github/GopuJayaAkash/week1-ai-foundations/blob/main/python_oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CLASS AND OBJECT

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}")

# Creating object
s1 = Student("John", 20)

# Calling method
s1.display()
# Out:
# Name: John, Age: 20

# %% [markdown]
# CONSTRUCTOR METHOD

# %%
class Car:
    def __init__(self, brand):
        self.brand = brand

car1 = Car("Toyota")
print(car1.brand)
# Out:
# Toyota

# %% [markdown]
# INSTANCE VARIABLES AND METHODS

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def show(self):
        print(self.name, self.salary)

e1 = Employee("Alice", 50000)
e1.show()
# Out:
# Alice 50000

# %% [markdown]
# INHERITANCE

# %%
class Animal:
    def sound(self):
        print("Animal makes a sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

d = Dog()
d.sound()
d.bark()
# Out:
# Animal makes a sound
# Dog barks

# %% [markdown]
# POLYMORPHISM

# %%
class Bird:
    def sound(self):
        print("Bird chirps")

class Cat:
    def sound(self):
        print("Cat meows")

for animal in [Bird(), Cat()]:
    animal.sound()
# Out:
# Bird chirps
# Cat meows
